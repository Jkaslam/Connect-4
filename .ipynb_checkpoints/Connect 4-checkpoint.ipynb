# %%
import pandas as pd

data = pd.read_csv("connect-4data.csv")

data.head()
# Out:
#   Column1 Column2 Column3 Column4 Column5 Column6 Column7 Column8 Column9  \
# 0       b       b       b       b       b       b       b       b       b
# 1       b       b       b       b       b       b       b       b       b
# 2       b       b       b       b       b       b       o       b       b
# 3       b       b       b       b       b       b       b       b       b
# 4       o       b       b       b       b       b       b       b       b
#
#   Column10  ... Column34 Column35 Column36 Column37 Column38 Column39  \
# 0        b  ...        b        b        b        b        b        b
# 1        b  ...        b        b        b        b        b        b
# 2        b  ...        b        b        b        b        b        b
# 3        b  ...        b        b        b        b        b        b
# 4        b  ...        b        b        b        b        b        b
#
#   Column40 Column41 Column42 Column43
# 0        b        b        b      win
# ...
